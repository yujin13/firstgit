# %%
import pandas as pd
import numpy as np

# %%
bond1 = pd.read_excel('中债-国开行债券总财富(1-3年)指数.xlsx',usecols=[2,6],index_col=0)['2003':]
bond5 = pd.read_excel('中债-国开行债券总财富(3-5年)指数.xlsx',usecols=[2,6],index_col=0)['2003':]
bond10 = pd.read_excel('中债-国开行债券总财富(7-10年)指数.xlsx',usecols=[2,6],index_col=0)['2003':]

# %%
bond1.head()
# Out:
#             收盘价(元)
# 日期
# 2003-01-31  100.88
# 2003-02-28  101.18
# 2003-03-31  101.21
# 2003-04-30  101.67
# 2003-05-30  101.83

# %%
bonds = pd.concat([bond1, bond5, bond10],axis = 1)
bonds.columns = ['1year','5year','10year']

# %%
bonds.plot()

# %%
monthR = bonds/bonds.shift(1)-1
monthR = monthR.fillna(0)
signal = bonds/bonds.shift(3)-1
signal = signal.fillna(0)

# %%
monthR.plot()

# %%
shortSignal = (signal['10year']<signal['1year']).shift(1)
shortSignal = shortSignal.fillna(0)
longSignal = (signal['10year']>signal['1year']).shift(1)
meanSignal = (signal['10year']==signal['1year']).shift(1)
momentumR = longSignal*monthR['10year']+shortSignal*monthR['1year']+meanSignal*(monthR['10year']+monthR['1year'])*0.5
momentumR = pd.DataFrame(momentumR.fillna(0),columns=['momentum'])
meanWeightR = pd.DataFrame(monthR[['1year','10year']].mean(axis=1),columns = ['1&10meanWeight'])
momentumAllR = pd.concat([monthR[['1year','10year']],meanWeightR,momentumR],axis=1)
momentumAll = ((momentumAllR+1).cumprod())*100

# %%
momentumAll.plot()

# %%
momentumAll[['momentum','1&10meanWeight']].plot()

# %%
TrueORnot = (momentumAllR['momentum']*2-momentumAllR['1year']-momentumAllR['10year'])>=0

# %%
pd.concat([momentumAllR[['1year','10year','momentum']],TrueORnot],axis=1)
# Out:
#                1year    10year  momentum      0
# 日期
# 2003-01-31  0.000000  0.000000  0.000000   True
# 2003-02-28  0.002974  0.003473  0.003223   True
# 2003-03-31  0.000297  0.009901  0.005099   True
# 2003-04-30  0.004545  0.005140  0.004842   True
# 2003-05-30  0.001574  0.008144  0.008144   True
# 2003-06-30  0.004714 -0.009393 -0.009393  False
# 2003-07-31 -0.005669  0.017732 -0.005669  False
# 2003-08-29  0.004718 -0.000745 -0.000745  False
# 2003-09-30 -0.002544 -0.017063 -0.017063  False
# 2003-10-31 -0.010593 -0.002466 -0.002466   True
# 2003-11-28  0.010608  0.008178  0.010608   True
# 2003-12-31  0.010300  0.014809  0.010300  False
# 2004-01-30  0.001359 -0.023422 -0.023422  False
# 2004-02-27  0.001842  0.008375  0.001842  False
# 2004-03-31  0.001645  0.005569  0.001645  False
# 2004-04-30  0.000773 -0.004224  0.000773   True
# 2004-05-31 -0.004152  0.005561  0.005561   True
# 2004-06-30  0.005914 -0.019310 -0.019310  False
# 2004-07-30 -0.005108  0.026094 -0.005108  False
# 2004-08-31  0.000000 -0.007359 -0.007359  False
# 2004-09-30  0.003972  0.002346  0.003972   True
# 2004-10-29 -0.001158 -0.010767 -0.010767  False
# 2004-11-30  0.004927  0.003691  0.004927   True
# 2004-12-31  0.003845  0.002169  0.003845   True
# 2005-01-31  0.010917  0.009409  0.010917   True
# 2005-02-28  0.006442  0.005872  0.006442   True
# 2005-03-31  0.006589  0.018071  0.006589  False
# 2005-04-30  0.009164  0.013017  0.013017   True
# 2005-05-31  0.003614 -0.001348 -0.001348  False
# 2005-06-30  0.006740  0.012777  0.012777   True
# ...              ...       ...       ...    ...
# 2016-12-31 -0.005975 -0.025007 -0.005975   True
# 2017-01-26  0.001673 -0.016573  0.001673   True
# 2017-02-28  0.001423 -0.003668  0.001423   True
# 2017-03-31  0.001112  0.002992  0.001112  False
# 2017-04-28  0.000679 -0.010095  0.000679   True
# 2017-05-31 -0.001480 -0.008054 -0.001480   True
# 2017-06-30  0.008585  0.017816  0.008585  False
# 2017-07-31  0.004532  0.003386  0.004532   True
# 2017-08-31 -0.000183 -0.004461 -0.004461  False
# 2017-09-30  0.003353  0.006492  0.006492   True
# 2017-10-31  0.000851 -0.015812  0.000851   True
# 2017-11-30 -0.001518 -0.017864 -0.001518   True
# 2017-12-31  0.002615  0.002008  0.002615   True
# 2018-01-31  0.006368 -0.008487  0.006368   True
# 2018-02-28  0.005424  0.016644  0.005424  False
# 2018-03-30  0.007313  0.015904  0.007313  False
# 2018-04-28  0.008152  0.017554  0.017554   True
# 2018-05-31  0.002951  0.005317  0.005317   True
# 2018-06-29  0.006886  0.017610  0.017610   True
# 2018-07-31  0.012625  0.008846  0.008846  False
# 2018-08-31  0.001732 -0.000384 -0.000384  False
# 2018-09-30  0.003572  0.002303  0.002303  False
# 2018-10-31  0.006029  0.014058  0.006029  False
# 2018-11-30  0.004337  0.018879  0.018879   True
# 2018-12-31  0.005342  0.015406  0.015406   True
# 2019-01-31  0.007178  0.003702  0.003702  False
# 2019-02-28  0.002133 -0.004415 -0.004415  False
# 2019-03-29  0.002520  0.006157  0.002520  False
# 2019-04-30 -0.002346 -0.008349 -0.002346   True
# 2019-05-21  0.004479  0.007582  0.004479  False
#
# [197 rows x 4 columns]
